# %%
 ===================================EDA Step========================================
    
- step-1 : Read the data 
        
        
- step-2 : Data Quick check 
          a) dtype columns shape size 
        
- step-3 : Convert categorical columns
        - Numerical columns name separtaeply 
    
- step-4 : You need fill the missing values
    
- step-5 : catogirical data analysis
        unique 
        nunique
        value counts
        bar chart 
        count plot 
        pie chart 
        
- step-6 : numerical data analysis 
           Describe function 
           Histogram
           Data skew ness
        
- step 7: Box plot creation 
          outlier analysis
        
- step-8: Transformation methods 
    
- step-9: Encoding methods
          map
          np.where
          LabelEncoder
          Onehot encoder
            
- step-10: Scaling Method 
           Z
           Minmax Scalar

            
            
1) Analytics Vidhya 
   Hackathons 
    They have some innsides
    ML
    DL
    NLP
    you need to upload the solution in therir 
    website=======rank
    
2) Kaggle

3) Uci machine learning Repository

=================================================================================
Columns === Features == variables 
columns are two types 


Input columns
 Independ                         Output columns
                                  Dpendent 
                                  traget columns

=======================================================================================

Rows ==== Fields ==== instances ==== tuples
values
